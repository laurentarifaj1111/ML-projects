# %%
import pandas as pd
import numpy as np
import seaborn as sb

import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
import sklearn.metrics as sm
from sklearn import datasets, linear_model, metrics

# %%
df = pd.read_csv('autos.csv', encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat     Offer
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat     Offer
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat     Offer
# 3  2016-03-17 16:54:04            GOLF_4_1_4__3Tï¿½RER  privat     Offer
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat     Offer
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# 0     150000                    0   benzin  volkswagen               NaN
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein
#
#            dateCreated  nrOfPictures  postalCode             lastSeen
# 0  2016-03-24 00:00:00             0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00             0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00             0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00             0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00             0       60437  2016-04-06 10:17:21

# %%
carsCopyDf = df.copy()

# %%
carsCopyDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  object
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          333659 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              351319 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                351044 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             338142 non-null  object
#  14  brand                371528 non-null  object
#  15  notRepairedDamage    299468 non-null  object
#  16  dateCreated          371528 non-null  object
#  17  nrOfPictures         371528 non-null  int64
#  18  postalCode           371528 non-null  int64
#  19  lastSeen             371528 non-null  object
# dtypes: int64(7), object(13)
# memory usage: 56.7+ MB

# %% [markdown]
# # Data preproccesing and visualisation

# %%
columnsToDrop=['name','dateCrawled','dateCreated','postalCode','lastSeen','nrOfPictures']

# %%
carsCopyDf = carsCopyDf.drop(columns= columnsToDrop)

# %%
carsCopyDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   seller               371528 non-null  object
#  1   offerType            371528 non-null  object
#  2   price                371528 non-null  int64
#  3   abtest               371528 non-null  object
#  4   vehicleType          333659 non-null  object
#  5   yearOfRegistration   371528 non-null  int64
#  6   gearbox              351319 non-null  object
#  7   powerPS              371528 non-null  int64
#  8   model                351044 non-null  object
#  9   kilometer            371528 non-null  int64
#  10  monthOfRegistration  371528 non-null  int64
#  11  fuelType             338142 non-null  object
#  12  brand                371528 non-null  object
#  13  notRepairedDamage    299468 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 39.7+ MB

# %%
carsCopyDf.isnull().sum()
# Out:
# seller                     0
# offerType                  0
# price                      0
# abtest                     0
# vehicleType            37869
# yearOfRegistration         0
# gearbox                20209
# powerPS                    0
# model                  20484
# kilometer                  0
# monthOfRegistration        0
# fuelType               33386
# brand                      0
# notRepairedDamage      72060
# dtype: int64

# %%
carsCopyDf = carsCopyDf.dropna()

# %%
sb.set(rc={'figure.figsize':(11.7,8.27)})

# %%
carsCopyDf = carsCopyDf.drop_duplicates(keep='first', inplace = False)

# %%
carsCopyDf.isnull().sum()
# Out:
# seller                 0
# offerType              0
# price                  0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# powerPS                0
# model                  0
# kilometer              0
# monthOfRegistration    0
# fuelType               0
# brand                  0
# notRepairedDamage      0
# dtype: int64

# %%
fig, ax = plt.subplots()
ax.scatter(x=carsCopyDf.yearOfRegistration, y=carsCopyDf.price)
ax.set_xlabel('yearOfRegistration')
ax.set_ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
fig, ax = plt.subplots()
ax.scatter(x=carsCopyDf.monthOfRegistration, y=carsCopyDf.price)
ax.set_xlabel('monthOfRegistration')
ax.set_ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
Q1 = np.percentile(carsCopyDf[carsCopyDf.yearOfRegistration < 2020].yearOfRegistration, 25, interpolation = 'midpoint')  
Q3 = np.percentile(carsCopyDf[carsCopyDf.yearOfRegistration < 2020].yearOfRegistration, 75, interpolation = 'midpoint')  

IQR = Q3 - Q1  
low_lim = Q1 - 1.5 * IQR 
up_lim = Q3 + 1.5 * IQR
low_lim
# Out:
# 1985.5

# %%
PQ1 = np.percentile(carsCopyDf.price, 25, interpolation = 'midpoint')  
PQ3 = np.percentile(carsCopyDf.price, 75, interpolation = 'midpoint')  

PIQR = PQ3 - PQ1  
Plow_lim = PQ1 - 1.5 * PIQR 
Pup_lim = PQ3 + 1.5 * PIQR
Plow_lim
Pup_lim
# Out:
# 19250.0

# %%
carsCopyDf = carsCopyDf[carsCopyDf.price < 17475]

# %%
carsCopyDf = carsCopyDf[carsCopyDf.yearOfRegistration > 1985 ]

# %%
carsCopyDf = carsCopyDf[carsCopyDf.monthOfRegistration < 2020 ]

# %%
carsCopyDf.monthOfRegistration = carsCopyDf.monthOfRegistration / 12

# %%
age = 2020 - carsCopyDf.yearOfRegistration + carsCopyDf.monthOfRegistration/12

# %%
carsCopyDf['age'] = age

# %%
carsCopyDf = carsCopyDf.drop(columns=['yearOfRegistration', 'monthOfRegistration'])

# %%
carsCopyDf = carsCopyDf[carsCopyDf.powerPS > 50]

# %%
carsCopyDf = carsCopyDf[carsCopyDf.powerPS < 1000]

# %%
priceColumn = carsCopyDf.price

# %%
carsCopyDf = carsCopyDf.drop(columns=['price'])

# %%
carsCopyDf['price'] = priceColumn

# %%
carsCopyDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209185 entries, 3 to 371525
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   seller             209185 non-null  object
#  1   offerType          209185 non-null  object
#  2   abtest             209185 non-null  object
#  3   vehicleType        209185 non-null  object
#  4   gearbox            209185 non-null  object
#  5   powerPS            209185 non-null  int64
#  6   model              209185 non-null  object
#  7   kilometer          209185 non-null  int64
#  8   fuelType           209185 non-null  object
#  9   brand              209185 non-null  object
#  10  notRepairedDamage  209185 non-null  object
#  11  age                209185 non-null  float64
#  12  price              209185 non-null  int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 22.3+ MB

# %%
fig, ax = plt.subplots()
ax.scatter(x=carsCopyDf.age, y=carsCopyDf.price)
plt.xlim(-1, 71)
ax.set_xlabel('Age')
ax.set_ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
carsCopyDf.price.mean()
# Out:
# 4922.735353873366

# %%
sb.countplot(carsCopyDf.seller)

# %%
sb.countplot(carsCopyDf.offerType)

# %%
sb.countplot(carsCopyDf.abtest)

# %%
sb.countplot(carsCopyDf.gearbox)

# %%
sb.countplot(carsCopyDf.brand)
plt.xticks(rotation=45)
sb.set(rc={'figure.figsize':(10,20)})

# %%
sb.set(rc={'figure.figsize':(11.7,8.27)})

# %%
sb.countplot(carsCopyDf.notRepairedDamage)

# %%
carsCopyDf = carsCopyDf[carsCopyDf['kilometer'] > 35000]

# %%
carsCopyDf = carsCopyDf.apply(LabelEncoder().fit_transform)

# %% [markdown]
# # Algorithms

# %%
X=carsCopyDf.iloc[:,:-1]
Y=carsCopyDf.iloc[:,-1]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
regressor = RandomForestRegressor(n_estimators=100, random_state=0)
regressor.fit(X_train, Y_train)
Y_pred = regressor.predict(X_test)

# %%
print("Mean absolute error =", round(sm.mean_absolute_error(Y_test, Y_pred), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(Y_test, Y_pred), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(Y_test, Y_pred), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(Y_test, Y_pred), 2)) 
print("R2 score =", round(sm.r2_score(Y_test, Y_pred), 2))
# Out:
# Mean absolute error = 200.03
# Mean squared error = 84733.28
# Median absolute error = 141.89
# Explain variance score = 0.86
# R2 score = 0.86

# %%
lReg = linear_model.LinearRegression() 
lReg.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print("R2 score =", format(lReg.score(X_test, Y_test)))
# Out:
# R2 score = 0.702264909420649

# %%
plt.scatter(lReg.predict(X_train), lReg.predict(X_train) - Y_train, 
            color = "green", s = 10, label = 'Train data') 
plt.scatter(lReg.predict(X_test), lReg.predict(X_test) - Y_test, 
            color = "blue", s = 10, label = 'Test data') 
plt.show()

# %%
knn = KNeighborsRegressor(n_neighbors=10)
#KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-f0915b302389> in <module>
# ----> 1 knn = KNeighborsRegressor(n_neighbors=10)
#       2 #KNeighborsClassifier(n_neighbors=10)
#       3 knn.fit(X_train, Y_train)
#
# NameError: name 'KNeighborsRegressor' is not defined

# %%
print(knn.score(X_test, Y_test))
# Out:
# 0.021919070578749034
